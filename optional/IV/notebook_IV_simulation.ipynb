# %% [markdown]
# # Optional: Instrumental Variables (IV) Simulation
#
# This notebook is an optional add-on. It demonstrates IV estimation with a simple simulation.
#
# **Learning goals**
# - Understand the IV assumptions (relevance, exclusion restriction, exchangeability/independence).
# - Compare naive regression vs IV (2SLS).
# - See what happens under a weak instrument.
#
# > TODO: This notebook is a scaffold and may be expanded by the instructor.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

rng = np.random.default_rng(564)

# TODO: simulate instrument Z, treatment A, outcome Y with unmeasured confounding U
# TODO: compare OLS vs IV/2SLS
